# %%
#import the necceasry library as shown by Dr.Venga
import tensorflow as tf
from tensorflow.keras import layers,models, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np

#Check if a GPU is used as my laptop had some issue
print("Num GPUs Available: " , len(tf.config.list_physical_devices('GPU')))

# Data Preparation-Cifar-10 data
print("Loading CIFAR-10 data...")
#CIFAR-10 contain 60,000 32 x 32 color images in 10 classes
cifar10 = tf.keras.datasets.cifar10
(train_images,train_labels),(test_images,test_labels) = cifar10.load_data()
#Images comes as integers from (0-255)
#Dividing by 255 scales them to a range of 0.0 to 1.0 as NN perform better in normalized input values
train_images,test_images = train_images/255.0, test_images/255.0

# Class name for the 10 categories in CIFAR-10
class_names = [ 'airplane','automobile', 'bird','cat','deer','dog', 'frog','horse','ship','truck']
#Cnn expect a 4D tensor:( Batch_Size, Height, Width(reshape the 28x28 images), Channels which will be 1 as MNIST is greyscale)
#train_images = train_images.reshape((60000,28,28,1)) # no need for now
#test_images = test_images.reshape((10000,28,28,1)) # no need for now

#Data Augmentation
# Adding some random flip, rotation and zoom to improve the way the model seeing the image.( Change of prespective and perceptive)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])



#2.Model Architecture

model =models.Sequential([
    #change to 32 x32 with 3 channels(RGB)
    Input(shape=(32,32,3)),

    #Apply data augmentation
    data_augmentation,

    #Block 1
    #This block have 32 filters that looks for simple things like vertical/horizontal line/edges and basic colours
    layers.Conv2D(32,(3,3),padding ='same',activation ='relu'), 
    layers.BatchNormalization(), #data trimming so no extreme value which make the learning faster and stable
    layers.Conv2D(32,(3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)), # make the model faster and felxible by shrinking the image size
    layers.Dropout(0.2), #Prevent overfitting

    #Block 2
    #This block have 64 filters which will combine block 1 to start seeing shapes and textures if any
    layers.Conv2D(64,(3,3),padding ='same',activation ='relu'), 
    layers.BatchNormalization(), #data trimming so no extreme value which make the learning faster and stable
    layers.Conv2D(64,(3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)), # make the model faster and felxible by shrinking the image size
    layers.Dropout(0.3), #Prevent overfitting

    #Block 3
    #This block have 128 filters which will combine block 1 and 2 to start seeing complex strutures like wings, wheel or beaks
    layers.Conv2D(128,(3,3),padding ='same',activation ='relu'), 
    layers.BatchNormalization(), #data trimming so no extreme value which make the learning faster and stable
    layers.Conv2D(128,(3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)), # make the model faster and felxible by shrinking the image size
    layers.Dropout(0.4), #Prevent overfitting
    
    #Final Classification layers
    # 1. Flatten to ocnverts the 2D features into a list of numbers
    layers.Flatten(),
    #Thinking layers
    layers.Dense(128,activation ='relu'),
    #data trimming
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10,activation = 'softmax'),
    
    
])

#Compilation
# usin adam as optimizer that automatically djust the learning rate
#loss where measures how wrng the model is using SparseCategorical is used for integer
#metric to track accuracy
#opt_sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9) going back to adam

model.compile(optimizer = 'adam',
              loss ='sparse_categorical_crossentropy',
              metrics=['accuracy'])

#print table showing the layers and number of trainable parameters
model.summary()

#Trying out Best Epoch Logic where it will compare the previous and present value and take the best value
# callback monitors val_accuracy and compares it to previous epochs
early_stop = EarlyStopping(
    monitor ='val_accuracy',
    patience=10,
    restore_best_weights = True, # this reload the best weight automatically
    verbose =1,
)

#This compares and saves only if the current epoch is better than previous best
checkpoint = ModelCheckpoint(
    'cifar10_model_v2_best.h5',
    monitor = 'val_accuracy',
    save_best_only = True,
    verbose = 1
)




#Training
#epochs = 60: The model looks at the entire dataset 60times as color images are more complex than digits
# 
print("\n Startng training with optimzer:adam")
history = model.fit(
                    train_images, train_labels,
                    epochs = 50,
                    validation_data = (test_images,test_labels),
                    batch_size = 64,
                    callbacks = [ early_stop,checkpoint]
            )

#Integration part where the model is saved
#saved file later moved to Webots controller folder
model.save('Final_cifar10_model.h5')
print("\n Model saved as 'Final_cifar10_model.h5' saved sucessfully")

#Evaluation and Summary
val_acc_history = history.history['val_accuracy']
best_epoch = np.argmax(val_acc_history) +1
best_val_acc = val_acc_history[best_epoch -1]

print("\n" + "="*30)
print(f"TRAINING SUMMARY")
print(f"Best Epoch Found: {best_epoch}")
print(f"Highest Val Accuracy achieved: {best_val_acc*100:.2f}%")
print(f"Model state restored to Best Epoch ({best_epoch}) weights.")
print("="*30)

test_loss,test_acc = model.evaluate(test_images, test_labels,verbose = 2)
print(f'\n Final Accuracy on Test Data:{test_acc*100:.2f}%')

#Prediction
#model.predict return an array of 10 possibilities for the image
prediction = model.predict(test_images[:1])
#argmax() piks the index(0-9) with the highest probability.
print(f"Model Prediction: {prediction.argmax()}")
print(f"Actual Label:{test_labels[0]}")

#Plotting graph

import matplotlib.pyplot as plt

# Plotting training history
plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid(True)

# Plot training & validation loss values
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Num GPUs Available:  0
# Loading CIFAR-10 data...
# C:\Users\USER\miniconda3\Lib\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 30, 30, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 30, 30, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 15, 15, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 15, 15, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 13, 13, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 6, 6, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 6, 6, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 4, 4, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 4, 4, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 356,266 (1.36 MB)
#  Trainable params: 355,114 (1.35 MB)
#  Non-trainable params: 1,152 (4.50 KB)
#  Startng training with optimzer:{model.optimizer.__.class__.__name__}(Momentum=0.9)
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.2829 - loss: 2.2600
# Epoch 1: val_accuracy improved from None to 0.51080, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 158s 193ms/step - accuracy: 0.3541 - loss: 1.8877 - val_accuracy: 0.5108 - val_loss: 1.3531
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.4808 - loss: 1.4535
# Epoch 2: val_accuracy improved from 0.51080 to 0.55540, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 163s 208ms/step - accuracy: 0.5019 - loss: 1.3973 - val_accuracy: 0.5554 - val_loss: 1.2434
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5524 - loss: 1.2596
# Epoch 3: val_accuracy improved from 0.55540 to 0.59320, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 198s 254ms/step - accuracy: 0.5617 - loss: 1.2382 - val_accuracy: 0.5932 - val_loss: 1.1595
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.5910 - loss: 1.1595
# Epoch 4: val_accuracy improved from 0.59320 to 0.62520, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 173s 221ms/step - accuracy: 0.6022 - loss: 1.1334 - val_accuracy: 0.6252 - val_loss: 1.0769
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6290 - loss: 1.0674
# Epoch 5: val_accuracy improved from 0.62520 to 0.63220, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 164s 210ms/step - accuracy: 0.6342 - loss: 1.0522 - val_accuracy: 0.6322 - val_loss: 1.0933
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.6479 - loss: 1.0185
# Epoch 6: val_accuracy improved from 0.63220 to 0.65310, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 183s 234ms/step - accuracy: 0.6563 - loss: 0.9979 - val_accuracy: 0.6531 - val_loss: 0.9986
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6644 - loss: 0.9570
# Epoch 7: val_accuracy improved from 0.65310 to 0.69640, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 212ms/step - accuracy: 0.6707 - loss: 0.9517 - val_accuracy: 0.6964 - val_loss: 0.8736
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6874 - loss: 0.9144
# Epoch 8: val_accuracy did not improve from 0.69640
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 166s 212ms/step - accuracy: 0.6885 - loss: 0.9114 - val_accuracy: 0.6699 - val_loss: 0.9752
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.6975 - loss: 0.8860
# Epoch 9: val_accuracy improved from 0.69640 to 0.70590, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 163s 208ms/step - accuracy: 0.6990 - loss: 0.8812 - val_accuracy: 0.7059 - val_loss: 0.8891
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.7028 - loss: 0.8548
# Epoch 10: val_accuracy improved from 0.70590 to 0.73380, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 198s 254ms/step - accuracy: 0.7049 - loss: 0.8548 - val_accuracy: 0.7338 - val_loss: 0.7687
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7136 - loss: 0.8315
# Epoch 11: val_accuracy improved from 0.73380 to 0.73730, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 241ms/step - accuracy: 0.7128 - loss: 0.8340 - val_accuracy: 0.7373 - val_loss: 0.7561
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7214 - loss: 0.8169
# Epoch 12: val_accuracy did not improve from 0.73730
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 165s 211ms/step - accuracy: 0.7212 - loss: 0.8164 - val_accuracy: 0.7098 - val_loss: 0.8673
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7259 - loss: 0.7997
# Epoch 13: val_accuracy improved from 0.73730 to 0.75030, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 157s 200ms/step - accuracy: 0.7274 - loss: 0.7988 - val_accuracy: 0.7503 - val_loss: 0.7400
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7315 - loss: 0.7893
# Epoch 14: val_accuracy improved from 0.75030 to 0.77210, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 219ms/step - accuracy: 0.7319 - loss: 0.7864 - val_accuracy: 0.7721 - val_loss: 0.6622
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7387 - loss: 0.7630
# Epoch 15: val_accuracy did not improve from 0.77210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 174s 222ms/step - accuracy: 0.7392 - loss: 0.7635 - val_accuracy: 0.7158 - val_loss: 0.8572
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7457 - loss: 0.7543
# Epoch 16: val_accuracy improved from 0.77210 to 0.77550, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 165s 211ms/step - accuracy: 0.7472 - loss: 0.7515 - val_accuracy: 0.7755 - val_loss: 0.6708
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7448 - loss: 0.7501
# Epoch 17: val_accuracy improved from 0.77550 to 0.78190, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 17: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 164s 209ms/step - accuracy: 0.7466 - loss: 0.7451 - val_accuracy: 0.7819 - val_loss: 0.6507
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.7487 - loss: 0.7394
# Epoch 18: val_accuracy did not improve from 0.78190
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 218s 278ms/step - accuracy: 0.7495 - loss: 0.7361 - val_accuracy: 0.7779 - val_loss: 0.6536
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.7542 - loss: 0.7249
# Epoch 19: val_accuracy did not improve from 0.78190
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 244s 312ms/step - accuracy: 0.7581 - loss: 0.7156 - val_accuracy: 0.7806 - val_loss: 0.6507
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.7575 - loss: 0.7101
# Epoch 20: val_accuracy improved from 0.78190 to 0.78510, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 240s 306ms/step - accuracy: 0.7591 - loss: 0.7099 - val_accuracy: 0.7851 - val_loss: 0.6370
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.7640 - loss: 0.7026
# Epoch 21: val_accuracy did not improve from 0.78510
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 227s 290ms/step - accuracy: 0.7618 - loss: 0.7037 - val_accuracy: 0.7661 - val_loss: 0.6793
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7631 - loss: 0.6940
# Epoch 22: val_accuracy improved from 0.78510 to 0.79810, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 230s 294ms/step - accuracy: 0.7655 - loss: 0.6915 - val_accuracy: 0.7981 - val_loss: 0.5902
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.7679 - loss: 0.6871
# Epoch 23: val_accuracy did not improve from 0.79810
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 236s 301ms/step - accuracy: 0.7665 - loss: 0.6887 - val_accuracy: 0.7916 - val_loss: 0.6232
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.7705 - loss: 0.6823
# Epoch 24: val_accuracy did not improve from 0.79810
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 225s 288ms/step - accuracy: 0.7703 - loss: 0.6826 - val_accuracy: 0.7981 - val_loss: 0.6055
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.7755 - loss: 0.6609
# Epoch 25: val_accuracy improved from 0.79810 to 0.81270, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 217s 277ms/step - accuracy: 0.7741 - loss: 0.6668 - val_accuracy: 0.8127 - val_loss: 0.5461
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.7750 - loss: 0.6617
# Epoch 26: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 266s 340ms/step - accuracy: 0.7737 - loss: 0.6653 - val_accuracy: 0.8021 - val_loss: 0.5812
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.7742 - loss: 0.6620
# Epoch 27: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 252s 323ms/step - accuracy: 0.7742 - loss: 0.6618 - val_accuracy: 0.7954 - val_loss: 0.5981
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.7791 - loss: 0.6452
# Epoch 28: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 257s 328ms/step - accuracy: 0.7772 - loss: 0.6532 - val_accuracy: 0.7851 - val_loss: 0.6421
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.7826 - loss: 0.6385
# Epoch 29: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 260s 333ms/step - accuracy: 0.7796 - loss: 0.6483 - val_accuracy: 0.7698 - val_loss: 0.6874
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7776 - loss: 0.6464
# Epoch 30: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 264s 337ms/step - accuracy: 0.7799 - loss: 0.6449 - val_accuracy: 0.8047 - val_loss: 0.5891
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7816 - loss: 0.6415
# Epoch 31: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 266s 340ms/step - accuracy: 0.7822 - loss: 0.6395 - val_accuracy: 0.8123 - val_loss: 0.5607
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.7851 - loss: 0.6381
# Epoch 32: val_accuracy did not improve from 0.81270
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 256s 327ms/step - accuracy: 0.7872 - loss: 0.6310 - val_accuracy: 0.8111 - val_loss: 0.5606
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.7926 - loss: 0.6138
# Epoch 33: val_accuracy improved from 0.81270 to 0.81590, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 33: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 252s 322ms/step - accuracy: 0.7887 - loss: 0.6251 - val_accuracy: 0.8159 - val_loss: 0.5442
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.7916 - loss: 0.6127
# Epoch 34: val_accuracy did not improve from 0.81590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 222s 284ms/step - accuracy: 0.7905 - loss: 0.6163 - val_accuracy: 0.8046 - val_loss: 0.5776
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.7934 - loss: 0.6090
# Epoch 35: val_accuracy did not improve from 0.81590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 220s 282ms/step - accuracy: 0.7909 - loss: 0.6169 - val_accuracy: 0.8089 - val_loss: 0.5688
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.7977 - loss: 0.5996
# Epoch 36: val_accuracy did not improve from 0.81590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 220s 281ms/step - accuracy: 0.7946 - loss: 0.6096 - val_accuracy: 0.8143 - val_loss: 0.5618
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.7935 - loss: 0.6093
# Epoch 37: val_accuracy improved from 0.81590 to 0.82200, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 37: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 224s 286ms/step - accuracy: 0.7949 - loss: 0.6096 - val_accuracy: 0.8220 - val_loss: 0.5209
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.7911 - loss: 0.6121
# Epoch 38: val_accuracy did not improve from 0.82200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 215s 274ms/step - accuracy: 0.7942 - loss: 0.6074 - val_accuracy: 0.8138 - val_loss: 0.5518
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.7937 - loss: 0.6003
# Epoch 39: val_accuracy did not improve from 0.82200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 224s 286ms/step - accuracy: 0.7942 - loss: 0.6027 - val_accuracy: 0.8198 - val_loss: 0.5283
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.7950 - loss: 0.6003
# Epoch 40: val_accuracy did not improve from 0.82200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 215s 275ms/step - accuracy: 0.7959 - loss: 0.6009 - val_accuracy: 0.8175 - val_loss: 0.5396
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.8011 - loss: 0.5846
# Epoch 41: val_accuracy did not improve from 0.82200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - accuracy: 0.7986 - loss: 0.5937 - val_accuracy: 0.8195 - val_loss: 0.5377
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.8006 - loss: 0.5843
# Epoch 42: val_accuracy improved from 0.82200 to 0.82290, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 42: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - accuracy: 0.8004 - loss: 0.5893 - val_accuracy: 0.8229 - val_loss: 0.5197
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8022 - loss: 0.5846
# Epoch 43: val_accuracy did not improve from 0.82290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - accuracy: 0.8021 - loss: 0.5858 - val_accuracy: 0.8185 - val_loss: 0.5309
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.8060 - loss: 0.5744
# Epoch 44: val_accuracy did not improve from 0.82290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - accuracy: 0.8011 - loss: 0.5849 - val_accuracy: 0.8046 - val_loss: 0.5826
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.8013 - loss: 0.5840
# Epoch 45: val_accuracy did not improve from 0.82290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 212s 272ms/step - accuracy: 0.8026 - loss: 0.5816 - val_accuracy: 0.8202 - val_loss: 0.5312
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.8008 - loss: 0.5882
# Epoch 46: val_accuracy improved from 0.82290 to 0.83300, saving model to cifar10_model_v2_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 46: finished saving model to cifar10_model_v2_best.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - accuracy: 0.8016 - loss: 0.5828 - val_accuracy: 0.8330 - val_loss: 0.4916
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.8019 - loss: 0.5845
# Epoch 47: val_accuracy did not improve from 0.83300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 231s 295ms/step - accuracy: 0.8027 - loss: 0.5806 - val_accuracy: 0.8313 - val_loss: 0.5066
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8056 - loss: 0.5738
# Epoch 48: val_accuracy did not improve from 0.83300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 259s 331ms/step - accuracy: 0.8045 - loss: 0.5767 - val_accuracy: 0.8301 - val_loss: 0.5068
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.8110 - loss: 0.5635
# Epoch 49: val_accuracy did not improve from 0.83300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 240s 306ms/step - accuracy: 0.8085 - loss: 0.5675 - val_accuracy: 0.8218 - val_loss: 0.5329
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8064 - loss: 0.5733
# Epoch 50: val_accuracy did not improve from 0.83300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 259s 330ms/step - accuracy: 0.8073 - loss: 0.5718 - val_accuracy: 0.8135 - val_loss: 0.5717
# Restoring model weights from the end of the best epoch: 46.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#  Model saved as 'Final_cifar10_model.h5' saved sucessfully
#
# ==============================
# TRAINING SUMMARY
# Best Epoch Found: 46
# Highest Val Accuracy achieved: 83.30%
# Model state restored to Best Epoch (46) weights.
# ==============================
# 313/313 - 13s - 42ms/step - accuracy: 0.8330 - loss: 0.4916
#
#  Final Accuracy on Test Data:83.30%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Model Prediction: 3
# Actual Label:[3]
